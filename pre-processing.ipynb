# %%
import pandas as pd
from pyTCTK import TextNet, WordNet
from vaderSentiment import SentimentIntensityAnalyzer
import warnings
warnings.filterwarnings("ignore")

# %%
df_data = pd.read_csv(filepath_or_buffer="amzn_customer_reviews.csv", sep=",")

# %%
df_data.head(5)
# Out:
#             Pseudo                                    Title  \
# 0  Assault Kittens  \nReally good option for portability.\n
# 1   Kenneth Cramer     \nExcellent portable gaming laptop\n
# 2  Assault Kittens      \nBEST 14inch Laptop in the World\n
# 3  Assault Kittens             \nWas great till it wasn't\n
# 4           Tanmay                         \nsolid laptop\n
#
#                                               Review              Rating  \
# 0  \nThis laptop is very impressive for its form ...  4.5 out of 5 stars
# 1  \nI'm writing this review for anyone who's on ...  5.0 out of 5 stars
# 2  \nI sold my M1 MacBook for this, and it was on...  1.0 out of 5 stars
# 3  \nThis laptop started off excellent. Screen lo...  5.0 out of 5 stars
# 4  \npros:1) keyboard: razer laptops are still th...  5.0 out of 5 stars
#
#    Verified Purchase                                            Date
# 0  Verified Purchase  Reviewed in the United States on June 18, 2021
# 1  Verified Purchase   Reviewed in the United States on July 7, 2021
# 2  Verified Purchase  Reviewed in the United States on June 18, 2021
# 3  Verified Purchase   Reviewed in the United States on July 7, 2021
# 4  Verified Purchase   Reviewed in the United States on July 1, 2021

# %%
df_data = TextNet(
    data=df_data,
    column="Review"
).remove_space()

df_data = TextNet(
    data=df_data,
    column="Title"
).remove_space()
df_data.head(3)
# Out:
#             Pseudo                                Title  \
# 0  Assault Kittens  Really good option for portability.
# 1   Kenneth Cramer     Excellent portable gaming laptop
# 2  Assault Kittens      BEST 14inch Laptop in the World
#
#                                               Review              Rating  \
# 0  This laptop is very impressive for its form fa...  4.5 out of 5 stars
# 1  I'm writing this review for anyone who's on th...  5.0 out of 5 stars
# 2  I sold my M1 MacBook for this, and it was one ...  1.0 out of 5 stars
#
#    Verified Purchase                                            Date
# 0  Verified Purchase  Reviewed in the United States on June 18, 2021
# 1  Verified Purchase   Reviewed in the United States on July 7, 2021
# 2  Verified Purchase  Reviewed in the United States on June 18, 2021

# %%
df_data = TextNet(
    data=df_data,
    column="Review"
).remove_whitespace()

df_data = TextNet(
    data=df_data,
    column="Title"
).remove_whitespace()

# %%
df_data = TextNet(
    data=df_data,
    column="Review"
).additional_cleaning(
    add_regexs=None
)

df_data = TextNet(
    data=df_data,
    column="Title"
).additional_cleaning(
    add_regexs=None
)

# %%
df_data.head(3)
# Out:
#             Pseudo                                Title  \
# 0  Assault Kittens  Really good option for portability.
# 1   Kenneth Cramer     Excellent portable gaming laptop
# 2  Assault Kittens      BEST 14inch Laptop in the World
#
#                                               Review              Rating  \
# 0  This laptop is very impressive for its form fa...  4.5 out of 5 stars
# 1  I'm writing this review for anyone who's on th...  5.0 out of 5 stars
# 2  I sold my M1 MacBook for this, and it was one ...  1.0 out of 5 stars
#
#    Verified Purchase                                            Date
# 0  Verified Purchase  Reviewed in the United States on June 18, 2021
# 1  Verified Purchase   Reviewed in the United States on July 7, 2021
# 2  Verified Purchase  Reviewed in the United States on June 18, 2021

# %%
vader = SentimentIntensityAnalyzer()

# %%
df_data["Score"] = df_data["Review"].apply(
    lambda review: vader.polarity_scores(review)
)
df_data["Compound"] = df_data["Score"].apply(
    lambda score_dict: score_dict["compound"]
)
df_data["Sentiment"] = df_data["Compound"].apply(
    lambda sent: "positive" if sent > 0 else ("neutral" if sent == 0 else "negative")
)

# %%
df_data["Sentiment"].value_counts()
# Out:
# Sentiment
# positive    907
# negative    156
# neutral      73
# Name: count, dtype: int64

# %%
df_data.head(3)
# Out:
#             Pseudo                                Title  \
# 0  Assault Kittens  Really good option for portability.
# 1   Kenneth Cramer     Excellent portable gaming laptop
# 2  Assault Kittens      BEST 14inch Laptop in the World
#
#                                               Review              Rating  \
# 0  This laptop is very impressive for its form fa...  4.5 out of 5 stars
# 1  I'm writing this review for anyone who's on th...  5.0 out of 5 stars
# 2  I sold my M1 MacBook for this, and it was one ...  1.0 out of 5 stars
#
#    Verified Purchase                                            Date  \
# 0  Verified Purchase  Reviewed in the United States on June 18, 2021
# 1  Verified Purchase   Reviewed in the United States on July 7, 2021
# 2  Verified Purchase  Reviewed in the United States on June 18, 2021
#
#                                                Score  Compound Sentiment
# 0  {'neg': 0.014, 'neu': 0.736, 'pos': 0.249, 'co...    0.9941  positive
# 1  {'neg': 0.016, 'neu': 0.88, 'pos': 0.104, 'com...    0.9921  positive
# 2  {'neg': 0.0, 'neu': 0.854, 'pos': 0.146, 'comp...    0.8779  positive

# %%
df_data = TextNet(
    data=df_data,
    column="Review"
).lowercase()

df_data = TextNet(
    data=df_data,
    column="Title"
).lowercase()
df_data.head(3)
# Out:
#             Pseudo                                Title  \
# 0  Assault Kittens  really good option for portability.
# 1   Kenneth Cramer     excellent portable gaming laptop
# 2  Assault Kittens      best 14inch laptop in the world
#
#                                               Review              Rating  \
# 0  this laptop is very impressive for its form fa...  4.5 out of 5 stars
# 1  i'm writing this review for anyone who's on th...  5.0 out of 5 stars
# 2  i sold my m1 macbook for this, and it was one ...  1.0 out of 5 stars
#
#    Verified Purchase                                            Date  \
# 0  Verified Purchase  Reviewed in the United States on June 18, 2021
# 1  Verified Purchase   Reviewed in the United States on July 7, 2021
# 2  Verified Purchase  Reviewed in the United States on June 18, 2021
#
#                                                Score  Compound Sentiment
# 0  {'neg': 0.014, 'neu': 0.736, 'pos': 0.249, 'co...    0.9941  positive
# 1  {'neg': 0.016, 'neu': 0.88, 'pos': 0.104, 'com...    0.9921  positive
# 2  {'neg': 0.0, 'neu': 0.854, 'pos': 0.146, 'comp...    0.8779  positive

# %%
df_data = TextNet(
    data=df_data,
    column="Review"
).remove_punctuation()

df_data = TextNet(
    data=df_data,
    column="Title"
).remove_punctuation()
df_data.head(3)
# Out:
#             Pseudo                               Title  \
# 0  Assault Kittens  really good option for portability
# 1   Kenneth Cramer    excellent portable gaming laptop
# 2  Assault Kittens     best 14inch laptop in the world
#
#                                               Review              Rating  \
# 0  this laptop is very impressive for its form fa...  4.5 out of 5 stars
# 1  i m writing this review for anyone who s on th...  5.0 out of 5 stars
# 2  i sold my m1 macbook for this and it was one o...  1.0 out of 5 stars
#
#    Verified Purchase                                            Date  \
# 0  Verified Purchase  Reviewed in the United States on June 18, 2021
# 1  Verified Purchase   Reviewed in the United States on July 7, 2021
# 2  Verified Purchase  Reviewed in the United States on June 18, 2021
#
#                                                Score  Compound Sentiment
# 0  {'neg': 0.014, 'neu': 0.736, 'pos': 0.249, 'co...    0.9941  positive
# 1  {'neg': 0.016, 'neu': 0.88, 'pos': 0.104, 'com...    0.9921  positive
# 2  {'neg': 0.0, 'neu': 0.854, 'pos': 0.146, 'comp...    0.8779  positive

# %%
df_data = TextNet(
    data=df_data,
    column="Review"
).remove_url()

df_data = TextNet(
    data=df_data,
    column="Title"
).remove_url()

# %%
df_data = TextNet(
    data=df_data,
    column="Review"
).remove_html()

df_data = TextNet(
    data=df_data,
    column="Title"
).remove_html()

# %%
df_data = TextNet(
    data=df_data,
    column="Review"
).remove_email()

df_data = TextNet(
    data=df_data,
    column="Title"
).remove_email()

# %%
df_data = TextNet(
    data=df_data,
    column="Review"
).remove_digit()

df_data = TextNet(
    data=df_data,
    column="Title"
).remove_digit()

# %%
df_data = TextNet(
    data=df_data,
    column="Review"
).remove_mention()

df_data = TextNet(
    data=df_data,
    column="Title"
).remove_mention()

# %%
df_data = TextNet(
    data=df_data,
    column="Review"
).remove_hastag()

df_data = TextNet(
    data=df_data,
    column="Title"
).remove_hastag()

# %%
df_data = TextNet(
    data=df_data,
    column="Review"
).remove_emoji()

df_data = TextNet(
    data=df_data,
    column="Title"
).remove_emoji()

# %%
stopwords_to_keep = [
    "doesn", "doesn't", "doesnt", "dont", "don't", "not", "wasn't", "wasnt",
    "aren", "aren't", "arent",  "couldn", "couldn't", "couldnt", "didn",
    "didn't", "didnt", "hadn", "hadn't", "hadnt",  "hasn", "hasn't", "hasnt",
    "haven't", "havent", "isn", "isn't", "isnt", "mightn",  "mightn't",
    "mightnt", "mustn", "mustn't", "mustnt", "needn", "needn't", "neednt",
    "shan", "shan't", "shant", "shouldn", "shouldn't", "shouldnt", "wasn",
    "wasn't",  "wasnt", "weren", "weren't", "werent", "won", "won't", "wont",
    "wouldn", "wouldn't", "wouldnt", "good", "bad", "worst", "wonderfull",
    "best", "better"
]

stopwords_to_add = [
    "es", "que", "en", "la", "las", "le", "les", "lo", "los", "de", "no",
    "el", "al", "un", "una", "se", "sa", "su", "sus", "por", "con", "mi",
    "para", "todo", "gb", "laptop", "computer", "pc"
]

# %%
df_data = WordNet(
    data=df_data,
    column="Review"
).remove_stopword(
    language="english",
    lowercase=False,
    remove_accents=False,
    add_stopwords=stopwords_to_add,
    remove_stopwords=stopwords_to_keep
)

df_data = WordNet(
    data=df_data,
    column="Title"
).remove_stopword(
    language="english",
    lowercase=False,
    remove_accents=False,
    add_stopwords=stopwords_to_add,
    remove_stopwords=stopwords_to_keep
)
df_data.head(3)
# Out:
#             Pseudo                           Title  \
# 0  Assault Kittens  really good option portability
# 1   Kenneth Cramer       excellent portable gaming
# 2  Assault Kittens                 best inch world
#
#                                               Review              Rating  \
# 0  impressive form factor really good balance siz...  4.5 out of 5 stars
# 1  writing review anyone fence purchasing   since...  5.0 out of 5 stars
# 2  sold macbook best decisions lifeif used macboo...  1.0 out of 5 stars
#
#    Verified Purchase                                            Date  \
# 0  Verified Purchase  Reviewed in the United States on June 18, 2021
# 1  Verified Purchase   Reviewed in the United States on July 7, 2021
# 2  Verified Purchase  Reviewed in the United States on June 18, 2021
#
#                                                Score  Compound Sentiment
# 0  {'neg': 0.014, 'neu': 0.736, 'pos': 0.249, 'co...    0.9941  positive
# 1  {'neg': 0.016, 'neu': 0.88, 'pos': 0.104, 'com...    0.9921  positive
# 2  {'neg': 0.0, 'neu': 0.854, 'pos': 0.146, 'comp...    0.8779  positive

# %%
df_data = WordNet(
    data=df_data,
    column="Review"
).lemmatize(
    language="english",
    lowercase=False,
    remove_accents=False
)

df_data = WordNet(
    data=df_data,
    column="Title"
).lemmatize(
    language="english",
    lowercase=False,
    remove_accents=False
)
df_data.head(3)
# Out:
#             Pseudo                           Title  \
# 0  Assault Kittens  really good option portability
# 1   Kenneth Cramer          excellent portable gam
# 2  Assault Kittens                 best inch world
#
#                                               Review              Rating  \
# 0  impressive form factor really good balance siz...  4.5 out of 5 stars
# 1  writ review anyo fence purchas   since really ...  5.0 out of 5 stars
# 2  sold macbook best decision lifeif us macbook y...  1.0 out of 5 stars
#
#    Verified Purchase                                            Date  \
# 0  Verified Purchase  Reviewed in the United States on June 18, 2021
# 1  Verified Purchase   Reviewed in the United States on July 7, 2021
# 2  Verified Purchase  Reviewed in the United States on June 18, 2021
#
#                                                Score  Compound Sentiment
# 0  {'neg': 0.014, 'neu': 0.736, 'pos': 0.249, 'co...    0.9941  positive
# 1  {'neg': 0.016, 'neu': 0.88, 'pos': 0.104, 'com...    0.9921  positive
# 2  {'neg': 0.0, 'neu': 0.854, 'pos': 0.146, 'comp...    0.8779  positive

# %%
df_data.drop(index=[282, 749, 859, 883, 1013, 1014, 1061], axis=0, inplace=True)
df_data.reset_index(drop=True, inplace=True)
df_data.head(3)
# Out:
#             Pseudo                           Title  \
# 0  Assault Kittens  really good option portability
# 1   Kenneth Cramer          excellent portable gam
# 2  Assault Kittens                 best inch world
#
#                                               Review              Rating  \
# 0  impressive form factor really good balance siz...  4.5 out of 5 stars
# 1  writ review anyo fence purchas   since really ...  5.0 out of 5 stars
# 2  sold macbook best decision lifeif us macbook y...  1.0 out of 5 stars
#
#    Verified Purchase                                            Date  \
# 0  Verified Purchase  Reviewed in the United States on June 18, 2021
# 1  Verified Purchase   Reviewed in the United States on July 7, 2021
# 2  Verified Purchase  Reviewed in the United States on June 18, 2021
#
#                                                Score  Compound Sentiment
# 0  {'neg': 0.014, 'neu': 0.736, 'pos': 0.249, 'co...    0.9941  positive
# 1  {'neg': 0.016, 'neu': 0.88, 'pos': 0.104, 'com...    0.9921  positive
# 2  {'neg': 0.0, 'neu': 0.854, 'pos': 0.146, 'comp...    0.8779  positive

# %%
df_data = TextNet(
    data=df_data,
    column="Review"
).remove_whitespace()

df_data = TextNet(
    data=df_data,
    column="Title"
).remove_whitespace()

# %%
df_data.head(5)
# Out:
#             Pseudo                           Title  \
# 0  Assault Kittens  really good option portability
# 1   Kenneth Cramer          excellent portable gam
# 2  Assault Kittens                 best inch world
# 3  Assault Kittens                 great till wasn
# 4           Tanmay                           solid
#
#                                               Review              Rating  \
# 0  impressive form factor really good balance siz...  4.5 out of 5 stars
# 1  writ review anyo fence purchas since really co...  5.0 out of 5 stars
# 2  sold macbook best decision lifeif us macbook y...  1.0 out of 5 stars
# 3  start excellent scre look great track pad grea...  5.0 out of 5 stars
# 4  pro keyboard razer laptop still keyboard type ...  5.0 out of 5 stars
#
#    Verified Purchase                                            Date  \
# 0  Verified Purchase  Reviewed in the United States on June 18, 2021
# 1  Verified Purchase   Reviewed in the United States on July 7, 2021
# 2  Verified Purchase  Reviewed in the United States on June 18, 2021
# 3  Verified Purchase   Reviewed in the United States on July 7, 2021
# 4  Verified Purchase   Reviewed in the United States on July 1, 2021
#
#                                                Score  Compound Sentiment
# 0  {'neg': 0.014, 'neu': 0.736, 'pos': 0.249, 'co...    0.9941  positive
# 1  {'neg': 0.016, 'neu': 0.88, 'pos': 0.104, 'com...    0.9921  positive
# 2  {'neg': 0.0, 'neu': 0.854, 'pos': 0.146, 'comp...    0.8779  positive
# 3  {'neg': 0.027, 'neu': 0.788, 'pos': 0.185, 'co...    0.9377  positive
# 4  {'neg': 0.035, 'neu': 0.888, 'pos': 0.077, 'co...    0.8526  positive

# %%
def feature_rating(text, dataframe) -> pd.core.frame.DataFrame:
    """
    Function that extracts the customer's rating and converts it to a float.
    
    Parameters
    ----------
    text : str or pandas.core.series.Series
        Text from which to extract the client's note.
    
    dataframe : pandas.core.frame.DataFrame
        Dataframe that allows the extraction of the final results.

    Returns
    -------
    pandas.core.frame.DataFrame
        Dataframe that contains the final result.

    """
    rating = []
    for i in range(0, len(text)):
        row = text[i].split(" ")
        row = row[0].replace(",", ".")
        row = float(row)
        rating.append(row)
    
    df_data = pd.DataFrame({"New rating": rating})
    dataframe = pd.concat([dataframe, df_data["New rating"]], axis=1)
    
    return dataframe

df_data = feature_rating(text=df_data["Rating"], dataframe=df_data)

# %%
from dateutil import parser
def feature_date(text, dataframe) -> pd.core.frame.DataFrame:
    """
    Function to extract the date from a text and convert it to datetime.

    Parameters
    ----------
    text : str or pandas.core.series.Series
        Text from which to extract the review's date.
    
    dataframe : pandas.core.frame.DataFrame
        Dataframe that allows the extraction of the final results.

    Returns
    -------
    pandas.core.frame.DataFrame
        Dataframe that contains the final result.

    """
    root = {
        "January": "01", "january": "01",
        "February": "02", "february": "02",
        "March": "03", "march": "03",
        "April": "04", "april": "04",
        "May": "05", "may": "05",
        "June": "06", "june": "06",
        "July": "07", "july": "07",
        "August": "08", "august": "08",
        "September": "09", "september": "09",
        "0ctober": "10", "october": "10",
        "November": "11", "november": "11",
        "December": "12", "december": "12"
    }

    dates = []
    for date_string in text:
        try:
            parsed_date = parser.parse(date_string, fuzzy=True)
            dates.append(parsed_date)
        except ValueError:
            # Handle the error or add default value for invalid dates
            dates.append(None)  # You can replace None with a default date if needed
    
    df_data = pd.DataFrame({"New date": dates})
    dataframe = pd.concat([dataframe, df_data["New date"]], axis=1)
    
    return dataframe
    
 
    

df_data = feature_date(text=df_data["Date"], dataframe=df_data)

# %%
df_data["Verified Purchase"].replace(
    to_replace="Verified Purchase",
    value="Yes",
    inplace=True
)

# %%
def feature_country(text, dataframe) -> pd.core.frame.DataFrame:
    """
    Function to extract the country from a text.

    Parameters
    ----------
    text : str or pandas.core.series.Series
        Text from which to extract the review's country.
    
    dataframe : pandas.core.frame.DataFrame
        Dataframe that allows the extraction of the final results.

    Returns
    -------
    pandas.core.frame.DataFrame
        Dataframe that contains the final result.

    """
    country = []
    for i in range(0, len(text)):
        row = text[i].split(" ")
        row = row[3] + " " + row[4]
        country.append(row)
    
    df_data = pd.DataFrame({"Country": country})
    dataframe = pd.concat([dataframe, df_data["Country"]], axis=1)
    
    return dataframe

df_data = feature_country(text=df_data["Date"], dataframe=df_data)

# %%
df_data.head(5)
# Out:
#             Pseudo                           Title  \
# 0  Assault Kittens  really good option portability
# 1   Kenneth Cramer          excellent portable gam
# 2  Assault Kittens                 best inch world
# 3  Assault Kittens                 great till wasn
# 4           Tanmay                           solid
#
#                                               Review              Rating  \
# 0  impressive form factor really good balance siz...  4.5 out of 5 stars
# 1  writ review anyo fence purchas since really co...  5.0 out of 5 stars
# 2  sold macbook best decision lifeif us macbook y...  1.0 out of 5 stars
# 3  start excellent scre look great track pad grea...  5.0 out of 5 stars
# 4  pro keyboard razer laptop still keyboard type ...  5.0 out of 5 stars
#
#   Verified Purchase                                            Date  \
# 0               Yes  Reviewed in the United States on June 18, 2021
# 1               Yes   Reviewed in the United States on July 7, 2021
# 2               Yes  Reviewed in the United States on June 18, 2021
# 3               Yes   Reviewed in the United States on July 7, 2021
# 4               Yes   Reviewed in the United States on July 1, 2021
#
#                                                Score  Compound Sentiment  \
# 0  {'neg': 0.014, 'neu': 0.736, 'pos': 0.249, 'co...    0.9941  positive
# 1  {'neg': 0.016, 'neu': 0.88, 'pos': 0.104, 'com...    0.9921  positive
# 2  {'neg': 0.0, 'neu': 0.854, 'pos': 0.146, 'comp...    0.8779  positive
# 3  {'neg': 0.027, 'neu': 0.788, 'pos': 0.185, 'co...    0.9377  positive
# 4  {'neg': 0.035, 'neu': 0.888, 'pos': 0.077, 'co...    0.8526  positive
#
#    New rating  New rating   New date        Country
# 0         4.5         4.5 2021-06-18  United States
# 1         5.0         5.0 2021-07-07  United States
# 2         1.0         1.0 2021-06-18  United States
# 3         5.0         5.0 2021-07-07  United States
# 4         5.0         5.0 2021-07-01  United States

# %%
import os
original_file_name = "amzn_customer_reviews.csv"
new_file_name = original_file_name.replace('.csv', '_cleaned.csv')
# Specify the desired path
desired_path = 'C:/Users/asmae/Desktop/PNLP'
full_new_file_path = os.path.join(desired_path, new_file_name)
df_data.to_csv(full_new_file_path, index=False)

print(f"File saved to {full_new_file_path}")
# Out:
# File saved to C:/Users/asmae/Desktop/PNLP\amzn_customer_reviews_cleaned.csv
